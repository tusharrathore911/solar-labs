# %%
from rest_framework import serializers 
class CountryInfoSerializer(serializers.Serializer): 
    flag_link = serializers.URLField() 
    capital = serializers.ListField(child=serializers.CharField()) 
    largest_city = serializers.CharField() 
    official_languages = serializers.ListField(child=serializers.CharField()) 
    area_total = serializers.IntegerField() 
    population = serializers.CharField() 
    GDP_nominal = serializers.CharField()
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15552\728938851.py in <module>
# ----> 1 from rest_framework import serializers
#       2 class CountryInfoSerializer(serializers.Serializer):
#       3     flag_link = serializers.URLField()
#       4     capital = serializers.ListField(child=serializers.CharField())
#       5     largest_city = serializers.CharField()
#
# c:\Users\tusha\AppData\Local\Programs\Python\Python37\lib\site-packages\rest_framework\serializers.py in <module>
#      28 from django.utils.translation import ugettext_lazy as _
#      29
# ---> 30 from rest_framework.compat import JSONField as ModelJSONField
#      31 from rest_framework.compat import postgres_fields, set_many, unicode_to_repr
#      32 from rest_framework.exceptions import ErrorDetail, ValidationError
#
# c:\Users\tusha\AppData\Local\Programs\Python\Python37\lib\site-packages\rest_framework\compat.py in <module>
#     159 # contrib.postgres only supported from 1.8 onwards.
#     160 try:
# --> 161     from django.contrib.postgres import fields as postgres_fields
#     162 except ImportError:
#     163     postgres_fields = None
#
# c:\Users\tusha\AppData\Local\Programs\Python\Python37\lib\site-packages\django\contrib\postgres\fields\__init__.py in <module>
# ----> 1 from .array import *  # NOQA
#       2 from .hstore import *  # NOQA
#       3 from .jsonb import *  # NOQA
#       4 from .ranges import *  # NOQA
#
# c:\Users\tusha\AppData\Local\Programs\Python\Python37\lib\site-packages\django\contrib\postgres\fields\array.py in <module>
#       1 import json
#       2
# ----> 3 from django.contrib.postgres import lookups
#       4 from django.contrib.postgres.forms import SimpleArrayField
#       5 from django.contrib.postgres.validators import ArrayMaxLengthValidator
#
# c:\Users\tusha\AppData\Local\Programs\Python\Python37\lib\site-packages\django\contrib\postgres\lookups.py in <module>
#       2 from django.utils.encoding import force_text
#       3
# ----> 4 from .search import SearchVector, SearchVectorExact, SearchVectorField
#       5
#       6
#
# c:\Users\tusha\AppData\Local\Programs\Python\Python37\lib\site-packages\django\contrib\postgres\search.py in <module>
#      45
#      46
# ---> 47 class SearchVector(SearchVectorCombinable, Func):
#      48     function = 'to_tsvector'
#      49     arg_joiner = " || ' ' || "
#
# c:\Users\tusha\AppData\Local\Programs\Python\Python37\lib\site-packages\django\contrib\postgres\search.py in SearchVector()
#      48     function = 'to_tsvector'
#      49     arg_joiner = " || ' ' || "
# ---> 50     _output_field = SearchVectorField()
#      51     config = None
#      52
#
# c:\Users\tusha\AppData\Local\Programs\Python\Python37\lib\site-packages\django\db\models\fields\__init__.py in __init__(self, verbose_name, name, primary_key, max_length, unique, blank, null, db_index, rel, default, editable, serialize, unique_for_date, unique_for_month, unique_for_year, choices, help_text, db_column, db_tablespace, auto_created, validators, error_messages)
#     164         self.db_index = db_index
#     165         self.db_column = db_column
# --> 166         self.db_tablespace = db_tablespace or settings.DEFAULT_INDEX_TABLESPACE
#     167         self.auto_created = auto_created
#     168
#
# c:\Users\tusha\AppData\Local\Programs\Python\Python37\lib\site-packages\django\conf\__init__.py in __getattr__(self, name)
#      51     def __getattr__(self, name):
#      52         if self._wrapped is empty:
# ---> 53             self._setup(name)
#      54         return getattr(self._wrapped, name)
#      55
#
# c:\Users\tusha\AppData\Local\Programs\Python\Python37\lib\site-packages\django\conf\__init__.py in _setup(self, name)
#      37                 "You must either define the environment variable %s "
#      38                 "or call settings.configure() before accessing settings."
# ---> 39                 % (desc, ENVIRONMENT_VARIABLE))
#      40
#      41         self._wrapped = Settings(settings_module)
#
# ImproperlyConfigured: Requested setting DEFAULT_INDEX_TABLESPACE, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.
